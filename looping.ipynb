# %%
counter = 1
while counter <= 10:
    print("loop counter",counter + 1)
    counter = counter + 1
# Out:
# loop counter 2
# loop counter 3
# loop counter 4
# loop counter 5
# loop counter 6
# loop counter 7
# loop counter 8
# loop counter 9
# loop counter 10
# loop counter 11

# %%
counter = 2
while counter <= 20:
    print("loop counter", counter + 2)
    counter = counter + 2
# Out:
# loop counter 4
# loop counter 6
# loop counter 8
# loop counter 10
# loop counter 12
# loop counter 14
# loop counter 16
# loop counter 18
# loop counter 20
# loop counter 22

# %%
counter = 1
while counter <= 5:
    print("loop count", counter + 1)
    counter = counter + 1
# Out:
# loop count 2
# loop count 3
# loop count 4
# loop count 5
# loop count 6

# %%
counter = 2
while counter < 30:
    print("loop counter", counter + 2)
    counter = counter + 2
# Out:
# loop counter 4
# loop counter 6
# loop counter 8
# loop counter 10
# loop counter 12
# loop counter 14
# loop counter 16
# loop counter 18
# loop counter 20
# loop counter 22
# loop counter 24
# loop counter 26
# loop counter 28
# loop counter 30

# %%
counter = 3
while counter < 40:
    print("loop counter", counter + 3)
    counter = counter + 3
# Out:
# loop counter 6
# loop counter 9
# loop counter 12
# loop counter 15
# loop counter 18
# loop counter 21
# loop counter 24
# loop counter 27
# loop counter 30
# loop counter 33
# loop counter 36
# loop counter 39
# loop counter 42

# %%
counter = 1
while counter < 10:
    print("loop counter", counter + 1)
    counter = counter + 1
# Out:
# loop counter 2
# loop counter 3
# loop counter 4
# loop counter 5
# loop counter 6
# loop counter 7
# loop counter 8
# loop counter 9
# loop counter 10

# %%
counter = 5
while counter < 50:
    print("loop counter", counter + 5)
    counter = counter + 5
# Out:
# loop counter 10
# loop counter 15
# loop counter 20
# loop counter 25
# loop counter 30
# loop counter 35
# loop counter 40
# loop counter 45
# loop counter 50
